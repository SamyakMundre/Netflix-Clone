# %% [markdown]
# <a href="https://colab.research.google.com/github/SamyakMundre/Netflix-Clone/blob/main/IPL2025AnalysisData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/IPL2025Batters.csv")

# %%
df.head()
# Out:
#          Player Name Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0      Sai Sudharsan   GT   759       15   15   1  108*  54.21  486  156.17
# 1  Surya Kumar Yadav   MI   717       16   16   5   73*  65.18  427  167.91
# 2        Virat Kohli  RCB   657       15   15   3   73*  54.75  454  144.71
# 3       Shubman Gill   GT   650       15   15   2   93*  50.00  417  155.87
# 4     Mitchell Marsh  LSG   627       13   13   0   117  48.23  383  163.70
#
#    100s  50s  4s  6s
# 0     1    6  88  21
# 1     0    5  69  38
# 2     0    8  66  19
# 3     0    6  62  24
# 4     1    6  56  37

# %%
df.tail()
# Out:
#           Player Name Team  Runs  Matches  Inn  No  HS   AVG  BF     SR  100s  \
# 151     Khaleel Ahmed  CSK     1       14    2   2  1*     -   2  50.00     0
# 152      Mohit Sharma   DC     1        8    2   1  1*  1.00   3  33.33     0
# 153  Donovan Ferreira   DC     1        1    1   0   1  1.00   3  33.33     0
# 154     Digvesh Singh  LSG     1       13    2   1   1  1.00   3  33.33     0
# 155    Manoj Bhandage  RCB     1        1    1   0   1  1.00   4  25.00     0
#
#      50s  4s  6s
# 151    0   0   0
# 152    0   0   0
# 153    0   0   0
# 154    0   0   0
# 155    0   0   0

# %%
df.shape
# Out:
# (156, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Player Name  156 non-null    object
#  1   Team         156 non-null    object
#  2   Runs         156 non-null    int64
#  3   Matches      156 non-null    int64
#  4   Inn          156 non-null    int64
#  5   No           156 non-null    int64
#  6   HS           156 non-null    object
#  7   AVG          156 non-null    object
#  8   BF           156 non-null    int64
#  9   SR           156 non-null    float64
#  10  100s         156 non-null    int64
#  11  50s          156 non-null    int64
#  12  4s           156 non-null    int64
#  13  6s           156 non-null    int64
# dtypes: float64(1), int64(9), object(4)
# memory usage: 17.2+ KB

# %%
df.describe()
# Out:
#              Runs     Matches         Inn          No          BF          SR  \
# count  156.000000  156.000000  156.000000  156.000000  156.000000  156.000000
# mean   161.320513    9.865385    7.153846    1.634615  105.673077  134.394103
# std    180.352772    4.757455    4.810142    1.658163  112.191838   57.237148
# min      1.000000    1.000000    1.000000    0.000000    1.000000   25.000000
# 25%     10.750000    6.000000    2.750000    0.000000   12.000000  100.000000
# 50%     93.500000   11.000000    6.000000    1.000000   63.500000  140.005000
# 75%    254.250000   14.000000   12.000000    3.000000  164.750000  162.707500
# max    759.000000   17.000000   17.000000    7.000000  486.000000  400.000000
#
#              100s         50s          4s          6s
# count  156.000000  156.000000  156.000000  156.000000
# mean     0.057692    0.916667   14.391026    8.294872
# std      0.233912    1.590124   17.778774    9.515500
# ...

# %%
df.columns
# Out:
# Index(['Player Name', 'Team', 'Runs', 'Matches', 'Inn', 'No', 'HS', 'AVG',
#        'BF', 'SR', '100s', '50s', '4s', '6s'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Player Name     object
# Team            object
# Runs             int64
# Matches          int64
# Inn              int64
# No               int64
# HS              object
# AVG             object
# BF               int64
# SR             float64
# 100s             int64
# 50s              int64
# 4s               int64
# 6s               int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Player Name  156 non-null    object
#  1   Team         156 non-null    object
#  2   Runs         156 non-null    int64
#  3   Matches      156 non-null    int64
#  4   Inn          156 non-null    int64
#  5   No           156 non-null    int64
#  6   HS           156 non-null    object
#  7   AVG          156 non-null    object
#  8   BF           156 non-null    int64
#  9   SR           156 non-null    float64
#  10  100s         156 non-null    int64
#  11  50s          156 non-null    int64
#  12  4s           156 non-null    int64
#  13  6s           156 non-null    int64
# dtypes: float64(1), int64(9), object(4)
# memory usage: 17.2+ KB

# %%
df.isnull().sum()
# Out:
# Player Name    0
# Team           0
# Runs           0
# Matches        0
# Inn            0
# No             0
# HS             0
# AVG            0
# BF             0
# SR             0
# 100s           0
# 50s            0
# 4s             0
# 6s             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#              Runs     Matches         Inn          No          BF          SR  \
# count  156.000000  156.000000  156.000000  156.000000  156.000000  156.000000
# mean   161.320513    9.865385    7.153846    1.634615  105.673077  134.394103
# std    180.352772    4.757455    4.810142    1.658163  112.191838   57.237148
# min      1.000000    1.000000    1.000000    0.000000    1.000000   25.000000
# 25%     10.750000    6.000000    2.750000    0.000000   12.000000  100.000000
# 50%     93.500000   11.000000    6.000000    1.000000   63.500000  140.005000
# 75%    254.250000   14.000000   12.000000    3.000000  164.750000  162.707500
# max    759.000000   17.000000   17.000000    7.000000  486.000000  400.000000
#
#              100s         50s          4s          6s
# count  156.000000  156.000000  156.000000  156.000000
# mean     0.057692    0.916667   14.391026    8.294872
# std      0.233912    1.590124   17.778774    9.515500
# ...

# %%
df["Team"].unique()
# Out:
# array(['GT', 'MI', 'RCB', 'LSG', 'PBKS', 'RR', 'DC', 'SRH', 'KKR', 'CSK'],
#       dtype=object)

# %%
df["Team"].nunique()
# Out:
# 10

# %%
top_runs = df.sort_values(by="Runs",ascending = False)
top_runs.head(10)
# Out:
#          Player Name  Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0      Sai Sudharsan    GT   759       15   15   1  108*  54.21  486  156.17
# 1  Surya Kumar Yadav    MI   717       16   16   5   73*  65.18  427  167.91
# 2        Virat Kohli   RCB   657       15   15   3   73*  54.75  454  144.71
# 3       Shubman Gill    GT   650       15   15   2   93*  50.00  417  155.87
# 4     Mitchell Marsh   LSG   627       13   13   0   117  48.23  383  163.70
# 5       Shreyas Iyer  PBKS   604       17   17   5   97*  50.33  345  175.07
# 6   Yashasvi Jaiswal    RR   559       14   14   1    75  43.00  350  159.71
# 7  Prabhsimran Singh  PBKS   549       17   17   0    91  32.29  342  160.52
# 8          K L Rahul    DC   539       13   13   3  112*  53.90  360  149.72
# 9        Jos Buttler    GT   538       14   13   4   97*  59.78  330  163.03
#
#    100s  50s  4s  6s
# 0     1    6  88  21
# 1     0    5  69  38
# 2     0    8  66  19
# 3     0    6  62  24
# ...

# %%
df.sort_values(by="SR", ascending=False).head(10)
# Out:
#              Player Name  Team  Runs  Matches  Inn  No   HS    AVG   BF  \
# 137      Lockie Ferguson  PBKS     4        4    1   1   4*      -    1
# 124        Kwena Maphaka    RR     8        2    1   1   8*      -    2
# 129           Akash Deep   LSG     6        6    2   1   6*   6.00    2
# 84      Romario Shepherd   RCB    70        8    3   1  53*  35.00   24
# 109        Jamie Overton   CSK    15        3    2   2  11*      -    7
# 85           Urvil Patel   CSK    68        3    3   0   37  22.67   32
# 39   Vaibhav Suryavanshi    RR   252        7    7   0  101  36.00  122
# 125       Raj Angad Bawa    MI     8        3    1   1   8*      -    4
# 105         Kusal Mendis    GT    20        1    1   0   20  20.00   10
# 10       Nicholas Pooran   LSG   524       14   14   2  87*  43.67  267
#
#          SR  100s  50s  4s  6s
# 137  400.00     0    0   1   0
# 124  400.00     0    0   2   0
# 129  300.00     0    0   0   1
# 84   291.66     0    1   5   7
# ...

# %%
df.sort_values(by="6s", ascending=False).head(10)
# Out:
#           Player Name  Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 10    Nicholas Pooran   LSG   524       14   14   2   87*  43.67  267  196.25
# 5        Shreyas Iyer  PBKS   604       17   17   5   97*  50.33  345  175.07
# 1   Surya Kumar Yadav    MI   717       16   16   5   73*  65.18  427  167.91
# 4      Mitchell Marsh   LSG   627       13   13   0   117  48.23  383  163.70
# 7   Prabhsimran Singh  PBKS   549       17   17   0    91  32.29  342  160.52
# 6    Yashasvi Jaiswal    RR   559       14   14   1    75  43.00  350  159.71
# 14    Abhishek Sharma   SRH   439       14   13   0   141  33.77  227  193.39
# 17        Riyan Parag    RR   393       14   14   2    95  32.75  236  166.52
# 11   Heinrich Klaasen   SRH   487       13   13   2  105*  44.27  282  172.69
# 12      Priyansh Arya  PBKS   475       17   17   0   103  27.94  265  179.24
#
#     100s  50s  4s  6s
# 10     0    5  45  40
# 5      0    6  43  39
# 1      0    5  69  38
# ...

# %%
df.sort_values(by="4s", ascending=False).head(10)
# Out:
#           Player Name  Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0       Sai Sudharsan    GT   759       15   15   1  108*  54.21  486  156.17
# 1   Surya Kumar Yadav    MI   717       16   16   5   73*  65.18  427  167.91
# 2         Virat Kohli   RCB   657       15   15   3   73*  54.75  454  144.71
# 3        Shubman Gill    GT   650       15   15   2   93*  50.00  417  155.87
# 6    Yashasvi Jaiswal    RR   559       14   14   1    75  43.00  350  159.71
# 4      Mitchell Marsh   LSG   627       13   13   0   117  48.23  383  163.70
# 7   Prabhsimran Singh  PBKS   549       17   17   0    91  32.29  342  160.52
# 12      Priyansh Arya  PBKS   475       17   17   0   103  27.94  265  179.24
# 9         Jos Buttler    GT   538       14   13   4   97*  59.78  330  163.03
# 8           K L Rahul    DC   539       13   13   3  112*  53.90  360  149.72
#
#     100s  50s  4s  6s
# 0      1    6  88  21
# 1      0    5  69  38
# 2      0    8  66  19
# ...

# %%
df.sort_values(by="100s", ascending = False)
# Out:
#           Player Name Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0       Sai Sudharsan   GT   759       15   15   1  108*  54.21  486  156.17
# 11   Heinrich Klaasen  SRH   487       13   13   2  105*  44.27  282  172.69
# 8           K L Rahul   DC   539       13   13   3  112*  53.90  360  149.72
# 4      Mitchell Marsh  LSG   627       13   13   0   117  48.23  383  163.70
# 14    Abhishek Sharma  SRH   439       14   13   0   141  33.77  227  193.39
# ..                ...  ...   ...      ...  ...  ..   ...    ...  ...     ...
# 151     Khaleel Ahmed  CSK     1       14    2   2    1*      -    2   50.00
# 152      Mohit Sharma   DC     1        8    2   1    1*   1.00    3   33.33
# 153  Donovan Ferreira   DC     1        1    1   0     1   1.00    3   33.33
# 154     Digvesh Singh  LSG     1       13    2   1     1   1.00    3   33.33
# 155    Manoj Bhandage  RCB     1        1    1   0     1   1.00    4   25.00
#
#      100s  50s  4s  6s
# ...

# %%
df.sort_values(by = "50s", ascending= False).head(10)
# Out:
#           Player Name  Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 2         Virat Kohli   RCB   657       15   15   3   73*  54.75  454  144.71
# 0       Sai Sudharsan    GT   759       15   15   1  108*  54.21  486  156.17
# 3        Shubman Gill    GT   650       15   15   2   93*  50.00  417  155.87
# 4      Mitchell Marsh   LSG   627       13   13   0   117  48.23  383  163.70
# 6    Yashasvi Jaiswal    RR   559       14   14   1    75  43.00  350  159.71
# 5        Shreyas Iyer  PBKS   604       17   17   5   97*  50.33  345  175.07
# 1   Surya Kumar Yadav    MI   717       16   16   5   73*  65.18  427  167.91
# 9         Jos Buttler    GT   538       14   13   4   97*  59.78  330  163.03
# 10    Nicholas Pooran   LSG   524       14   14   2   87*  43.67  267  196.25
# 13      Aiden Markram   LSG   445       13   13   0    66  34.23  299  148.82
#
#     100s  50s  4s  6s
# 2      0    8  66  19
# 0      1    6  88  21
# 3      0    6  62  24
# ...

# %%
team_runs = df.groupby("Team")["Runs"].sum()
print(team_runs)
# Out:
# Team
# CSK     2315
# DC      2386
# GT      2766
# KKR     1886
# LSG     2598
# MI      2802
# PBKS    3000
# RCB     2539
# RR      2496
# SRH     2378
# Name: Runs, dtype: int64

# %%
team_runs.sort_values(ascending=False)
# Out:
# Team
# PBKS    3000
# MI      2802
# GT      2766
# LSG     2598
# RCB     2539
# RR      2496
# DC      2386
# SRH     2378
# CSK     2315
# KKR     1886
# Name: Runs, dtype: int64

# %%
df.groupby("Team")["SR"].mean().sort_values(ascending=False)
# Out:
# Team
# PBKS    144.912667
# GT      142.952857
# RCB     141.392857
# LSG     140.846667
# MI      137.221250
# RR      137.220000
# CSK     130.346842
# SRH     129.773571
# KKR     123.555333
# DC      119.012941
# Name: SR, dtype: float64

# %%
df.groupby("Team")["6s"].sum().sort_values(ascending=False)
# Out:
# Team
# PBKS    173
# LSG     152
# RR      146
# MI      142
# RCB     125
# GT      124
# SRH     120
# DC      109
# CSK     102
# KKR     101
# Name: 6s, dtype: int64

# %%
df.groupby("Team")["4s"].sum().sort_values(ascending=False)
# Out:
# Team
# MI      259
# GT      256
# PBKS    255
# RCB     238
# SRH     219
# DC      219
# LSG     218
# RR      209
# CSK     199
# KKR     173
# Name: 4s, dtype: int64

# %%
df["Runs"].sum()
# Out:
# np.int64(25166)

# %%
df["Runs"].mean()
# Out:
# np.float64(161.32051282051282)

# %%
df["Runs"].max()
# Out:
# 759

# %%
df["Runs"].min()
# Out:
# 1

# %%
df["SR"].mean()
# Out:
# np.float64(134.39410256410258)

# %%
df["AVG"]= pd.to_numeric(df["AVG"], errors = "coerce")

# %%
df["AVG"].isnull().sum()
# Out:
# np.int64(15)

# %%
df["AVG"].mean()
# Out:
# np.float64(23.08723404255319)

# %%
df.corr(numeric_only=True)
# Out:
#              Runs   Matches       Inn        No       AVG        BF        SR  \
# Runs     1.000000  0.562155  0.879385  0.218436  0.811337  0.990562  0.349464
# Matches  0.562155  1.000000  0.744069  0.520411  0.340449  0.566610  0.055588
# Inn      0.879385  0.744069  1.000000  0.442270  0.667311  0.885002  0.312416
# No       0.218436  0.520411  0.442270  1.000000  0.367618  0.220717  0.119068
# AVG      0.811337  0.340449  0.667311  0.367618  1.000000  0.791954  0.650401
# BF       0.990562  0.566610  0.885002  0.220717  0.791954  1.000000  0.302441
# SR       0.349464  0.055588  0.312416  0.119068  0.650401  0.302441  1.000000
# 100s     0.420423  0.180949  0.301697 -0.061737  0.290090  0.395299  0.143433
# 50s      0.874217  0.413836  0.662982  0.071571  0.674650  0.869373  0.245441
# 4s       0.972971  0.510460  0.820847  0.120210  0.761884  0.961525  0.332809
# 6s       0.930254  0.555838  0.855724  0.237079  0.762257  0.891057  0.404466
#
# ...

# %%
df[["Runs","AVG","SR","4s","6s"]].corr()
# Out:
#           Runs       AVG        SR        4s        6s
# Runs  1.000000  0.811337  0.349464  0.972971  0.930254
# AVG   0.811337  1.000000  0.650401  0.761884  0.762257
# SR    0.349464  0.650401  1.000000  0.332809  0.404466
# 4s    0.972971  0.761884  0.332809  1.000000  0.861225
# 6s    0.930254  0.762257  0.404466  0.861225  1.000000

# %%
df["Boundary Runs"] = (df["4s"]*4) + (df["6s"]*6)

# %%
df.head()
# Out:
#          Player Name Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0      Sai Sudharsan   GT   759       15   15   1  108*  54.21  486  156.17
# 1  Surya Kumar Yadav   MI   717       16   16   5   73*  65.18  427  167.91
# 2        Virat Kohli  RCB   657       15   15   3   73*  54.75  454  144.71
# 3       Shubman Gill   GT   650       15   15   2   93*  50.00  417  155.87
# 4     Mitchell Marsh  LSG   627       13   13   0   117  48.23  383  163.70
#
#    100s  50s  4s  6s  Boundary Runs
# 0     1    6  88  21            478
# 1     0    5  69  38            504
# 2     0    8  66  19            378
# 3     0    6  62  24            392
# 4     1    6  56  37            446

# %%
df[df["Runs"] > 500]
# Out:
#           Player Name  Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0       Sai Sudharsan    GT   759       15   15   1  108*  54.21  486  156.17
# 1   Surya Kumar Yadav    MI   717       16   16   5   73*  65.18  427  167.91
# 2         Virat Kohli   RCB   657       15   15   3   73*  54.75  454  144.71
# 3        Shubman Gill    GT   650       15   15   2   93*  50.00  417  155.87
# 4      Mitchell Marsh   LSG   627       13   13   0   117  48.23  383  163.70
# 5        Shreyas Iyer  PBKS   604       17   17   5   97*  50.33  345  175.07
# 6    Yashasvi Jaiswal    RR   559       14   14   1    75  43.00  350  159.71
# 7   Prabhsimran Singh  PBKS   549       17   17   0    91  32.29  342  160.52
# 8           K L Rahul    DC   539       13   13   3  112*  53.90  360  149.72
# 9         Jos Buttler    GT   538       14   13   4   97*  59.78  330  163.03
# 10    Nicholas Pooran   LSG   524       14   14   2   87*  43.67  267  196.25
#
# ...

# %%
df[df["SR"] > 150]
# Out:
#              Player Name  Team  Runs  Matches  Inn  No    HS    AVG   BF  \
# 0          Sai Sudharsan    GT   759       15   15   1  108*  54.21  486
# 1      Surya Kumar Yadav    MI   717       16   16   5   73*  65.18  427
# 3           Shubman Gill    GT   650       15   15   2   93*  50.00  417
# 4         Mitchell Marsh   LSG   627       13   13   0   117  48.23  383
# 5           Shreyas Iyer  PBKS   604       17   17   5   97*  50.33  345
# 6       Yashasvi Jaiswal    RR   559       14   14   1    75  43.00  350
# 7      Prabhsimran Singh  PBKS   549       17   17   0    91  32.29  342
# 9            Jos Buttler    GT   538       14   13   4   97*  59.78  330
# 10       Nicholas Pooran   LSG   524       14   14   2   87*  43.67  267
# 11      Heinrich Klaasen   SRH   487       13   13   2  105*  44.27  282
# 12         Priyansh Arya  PBKS   475       17   17   0   103  27.94  265
# 14       Abhishek Sharma   SRH   439       14   13   0   141  33.77  227
# ...

# %%
df[df["Team"]=="RCB"]
# Out:
#            Player Name Team  Runs  Matches  Inn  No   HS    AVG   BF      SR  \
# 2          Virat Kohli  RCB   657       15   15   3  73*  54.75  454  144.71
# 16           Phil Salt  RCB   403       13   13   1   65  33.58  229  175.98
# 28       Rajat Patidar  RCB   312       15   14   1   64  24.00  217  143.77
# 38       Jitesh Sharma  RCB   261       15   11   4  85*  37.29  148  176.35
# 41    Devdutt Padikkal  RCB   247       10   10   1   61  27.44  164  150.60
# 56           Tim David  RCB   187       12    9   6  50*  62.33  101  185.14
# 72    Liam Livingstone  RCB   112       10    8   1   54  16.00   84  133.33
# 73       Krunal Pandya  RCB   109       15    7   1  73*  18.17   86  126.74
# 77      Mayank Agarwal  RCB    95        4    4   1  41*  31.67   64  148.43
# 84    Romario Shepherd  RCB    70        8    3   1  53*  35.00   24  291.66
# 86       Jacob Bethell  RCB    67        2    2   0   55  33.50   39  171.79
# ...

# %%
df[(df["Runs"]>500)&(df["SR"]>150)]
# Out:
#           Player Name  Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0       Sai Sudharsan    GT   759       15   15   1  108*  54.21  486  156.17
# 1   Surya Kumar Yadav    MI   717       16   16   5   73*  65.18  427  167.91
# 3        Shubman Gill    GT   650       15   15   2   93*  50.00  417  155.87
# 4      Mitchell Marsh   LSG   627       13   13   0   117  48.23  383  163.70
# 5        Shreyas Iyer  PBKS   604       17   17   5   97*  50.33  345  175.07
# 6    Yashasvi Jaiswal    RR   559       14   14   1    75  43.00  350  159.71
# 7   Prabhsimran Singh  PBKS   549       17   17   0    91  32.29  342  160.52
# 9         Jos Buttler    GT   538       14   13   4   97*  59.78  330  163.03
# 10    Nicholas Pooran   LSG   524       14   14   2   87*  43.67  267  196.25
#
#     100s  50s  4s  6s  Boundary Runs
# 0      1    6  88  21            478
# 1      0    5  69  38            504
# 3      0    6  62  24            392
# 4      1    6  56  37            446
# ...

# %%
df.to_csv("IPL@)@%_Cleaned.csv", index=False)

# %%
# Out:
#            Player Name Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0        Sai Sudharsan   GT   759       15   15   1  108*  54.21  486  156.17
# 1    Surya Kumar Yadav   MI   717       16   16   5   73*  65.18  427  167.91
# 2          Virat Kohli  RCB   657       15   15   3   73*  54.75  454  144.71
# 3         Shubman Gill   GT   650       15   15   2   93*  50.00  417  155.87
# 4       Mitchell Marsh  LSG   627       13   13   0   117  48.23  383  163.70
# ..                 ...  ...   ...      ...  ...  ..   ...    ...  ...     ...
# 151      Khaleel Ahmed  CSK     1       14    2   2    1*    NaN    2   50.00
# 152       Mohit Sharma   DC     1        8    2   1    1*   1.00    3   33.33
# 153   Donovan Ferreira   DC     1        1    1   0     1   1.00    3   33.33
# 154      Digvesh Singh  LSG     1       13    2   1     1   1.00    3   33.33
# 155     Manoj Bhandage  RCB     1        1    1   0     1   1.00    4   25.00
#
# ...
