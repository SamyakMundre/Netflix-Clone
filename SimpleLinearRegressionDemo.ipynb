# %% [markdown]
# <a href="https://colab.research.google.com/github/SamyakMundre/Netflix-Clone/blob/main/SimpleLinearRegressionDemo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/placement1.csv')

# %%
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
df.shape
# Out:
# (200, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cgpa     200 non-null    float64
#  1   package  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
df.columns
# Out:
# Index(['cgpa', 'package'], dtype='object')

# %%
df.dtypes
# Out:
# cgpa       float64
# package    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#
sns.scatterplot(df['package'] )
plt.plot(df['cgpa'], df['package'], c="red")

# %%
X=df.iloc[:, 0:1].values

# %%
X
# Out:
# array([[6.89],
#        [5.12],
#        [7.82],
#        [7.42],
#        [6.94],
#        [7.89],
#        [6.73],
#        [6.75],
#        [6.09],
#        [8.31],
#        [5.32],
#        [6.61],
#        [8.94],
#        [6.93],
#        [7.73],
#        [7.25],
#        [6.84],
#        [5.38],
#        [6.94],
#        [7.48],
#        [7.28],
#        [6.85],
#        [6.14],
#        [6.19],
#        [6.53],
#        [7.28],
#        [8.31],
#        [5.42],
#        [5.94],
#        [7.15],
#        [7.36],
#        [8.1 ],
#        [6.96],
#        [6.35],
#        [7.34],
#        [6.87],
#        [5.99],
#        [5.9 ],
#        [8.62],
#        [7.43],
#        [9.38],
#        [6.89],
#        [5.95],
#        [7.66],
#        [5.09],
#        [7.87],
#        [6.07],
#        [5.84],
#        [8.63],
#        [8.87],
#        [9.58],
#        [9.26],
#        [8.37],
#        [6.47],
#        [6.86],
#        [8.2 ],
#        [5.84],
#        [6.6 ],
# ...

# %%
y=df.iloc[:, -1]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y,train_size=0.8,test_size=0.2, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (160, 1)
# (40, 1)
# (160,)
# (40,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_train, y_train)
# Out:
# 0.7758339025733345

# %%
yPred=lr.predict(X_test)

# %%
print(yPred)
# Out:
# [2.78031348 3.13635249 3.1995207  2.38981908 3.52684689 3.76803461
#  3.16506531 2.54486832 3.17655044 3.4923915  1.90744364 2.34962112
#  3.6876387  2.75734322 3.47516381 3.04447145 2.32665086 3.20526327
#  2.17734418 3.314372   2.45298729 2.90090734 3.32011456 2.87219451
#  3.33734226 2.19457187 1.41932564 2.7114027  3.18229301 2.32665086
#  3.74506435 2.95833298 3.68189614 2.97556068 2.59080884 3.34882738
#  2.47595755 3.07318428 4.17575671 2.95833298]

# %%
lr.coef_
# Out:
# array([0.57425647])

# %%
lr.intercept_
# Out:
# np.float64(-1.0270069374542108)

# %%
#y=mx+c
#y=0.57425647*7.9+(-1.0270069374542108)

# %%
lr.predict([[7.9]])
# Out:
# array([3.5096192])

# %%
lr.predict([[6.5]])
# Out:
# array([2.70566014])
